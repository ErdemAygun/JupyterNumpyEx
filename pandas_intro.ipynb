# %%
import pandas as pd
import numpy as np

# %%
d = {'col1': [10, 20], 'col2': [30, 40]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2
# 0    10    30
# 1    20    40

# %%
df["col1"][0] = 100
df
# Out:
#    col1  col2
# 0   100    30
# 1    20    40

# %%
data = pd.read_csv("titanic.csv", dtype={"Pclass": np.int8})  # using dtype parameter we can specify data type for any column
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int8
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), int8(1), object(5)
# memory usage: 77.6+ KB

# %%
data["Survived"] = data["Survived"].astype(bool)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1     False       3
# 1              2      True       1
# 2              3      True       3
# 3              4      True       1
# 4              5     False       3
# ..           ...       ...     ...
# 886          887     False       2
# 887          888      True       1
# 888          889     False       3
# 889          890      True       1
# 890          891     False       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data["Sex"] = data["Sex"].astype("category")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    bool
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: bool(1), category(1), float64(2), int64(4), object(4)
# memory usage: 71.6+ KB

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1     False       3
# 1              2      True       1
# 2              3      True       3
# 3              4      True       1
# 4              5     False       3
# ..           ...       ...     ...
# 886          887     False       2
# 887          888      True       1
# 888          889     False       3
# 889          890      True       1
# 890          891     False       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x = data.head(10)  # select first 10 rows
x.to_excel("first_rows.xlsx")

# %%
# To be able to select rows we need to use `loc` or `iloc` attribute
data.loc[0] # loc gives us access to rows by their index
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
last = data.tail(10) # select last 10 rows
last.loc[881]  # OK
last.iloc[0]  # .iloc gives access to rows by their position (iloc[0] will always return the first row)
last.iloc[1:5]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 882          883         0       3          Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2         Banfield, Mr. Frederick James
# 884          885         0       3                Sutehall, Mr. Henry Jr
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
